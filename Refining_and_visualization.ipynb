# %% [markdown]
# Import all the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import string
from wordcloud import WordCloud
import nltk
from collections import Counter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import nltk
import plotly.express as px
import plotly.figure_factory as ff
import seaborn as sns

nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer 
nltk.download('wordnet')
# %matplotlib inline
from plotly import graph_objs as go
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Shachi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Shachi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Shachi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.

# %% [markdown]
# # Data Refining

# %%
# Input file name
file_name = 'train_dataset.csv'
dataset = pd.read_csv(file_name)

# removed unwanted columns
df = dataset.drop(['full_text','Additional.Comments.x','Additional.Comments.y','sample_name','create_date','Unnamed: 0', 'Unnamed: 0.1','ID', 'user','userID','Sample.ID.x','Sample.ID.y','In.English.x', 'In.English.y','User.x', 'User.y'],axis=1)

# %%
# chk the new dataset columns
df
# Out:
#             key  RT_TF  Still.Exists.x  Still.Exists.y  Sarcasm.x  Sarcasm.y  \
# 0        JewNAS   True            True            True      False      False
# 1         JewAS   True            True            True      False      False
# 2         JewAS   True            True            True      False      False
# 3       KikesAS  False            True            True      False      False
# 4        JewNAS   True            True            True      False       True
# ...         ...    ...             ...             ...        ...        ...
# 3211     JewNAS  False            True            True      False      False
# 3212  ZioNaziAS  False            True            True      False      False
# 3213     JewNAS   True            True            True      False      False
# 3214     JewNAS   True            True            True      False      False
# 3215     JewNAS   True            True            True      False      False
#
#       Disagree.With.x  Disagree.With.y  Sentiment.Rating.x  \
# 0               False            False                   3
# 1               False            False                   2
# 2               False            False                   2
# 3               False            False                   2
# 4               False            False                   3
# ...               ...              ...                 ...
# 3211            False            False                   3
# 3212            False            False                   3
# 3213            False            False                   3
# 3214            False            False                   3
# 3215            False            False                   3
#
#       Sentiment.Rating.y  Calling.Out.x  Calling.Out.y  \
# 0                      3              1              0
# 1                      2              0              0
# 2                      2              0              0
# 3                      2              1              1
# 4                      3              0              1
# ...                  ...            ...            ...
# 3211                   3              0              0
# 3212                   1              0              0
# 3213                   3              1              0
# 3214                   3              1              0
# 3215                   4              0              0
#
#       Is.About.the.Holocaust.x  Is.About.the.Holocaust.y  IHRA.Section.x  \
# 0                          0.0                       0.0              13
# 1                          NaN                       NaN               2
# 2                          0.0                       0.0               2
# 3                          0.0                       0.0               0
# 4                          0.0                       0.0              13
# ...                        ...                       ...             ...
# 3211                       0.0                       0.0              13
# 3212                       0.0                       0.0              10
# 3213                       0.0                       0.0              13
# 3214                       0.0                       0.0              13
# 3215                       NaN                       NaN              13
#
#       IHRA.Section.y  Is.About.The.Holocaust.x  Is.About.The.Holocaust.y  \
# 0                 13                       NaN                       NaN
# 1                  2                       0.0                       0.0
# 2                  2                       NaN                       NaN
# 3                  0                       NaN                       NaN
# 4                 13                       NaN                       NaN
# ...              ...                       ...                       ...
# 3211              13                       NaN                       NaN
# 3212              10                       NaN                       NaN
# 3213              13                       NaN                       NaN
# 3214              13                       NaN                       NaN
# 3215              13                       1.0                       0.0
#
#       Target
# 0          0
# 1          1
# 2          1
# 3          1
# 4          0
# ...      ...
# 3211       0
# 3212       1
# 3213       0
# 3214       0
# 3215       0
#
# [3216 rows x 19 columns]

# %%
# get info of dataset to know aboout data types and null values if present
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3216 entries, 0 to 3215
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   key                       3216 non-null   object
#  1   RT_TF                     3216 non-null   bool
#  2   Still.Exists.x            3216 non-null   bool
#  3   Still.Exists.y            3216 non-null   bool
#  4   Sarcasm.x                 3216 non-null   bool
#  5   Sarcasm.y                 3216 non-null   bool
#  6   Disagree.With.x           3216 non-null   bool
#  7   Disagree.With.y           3216 non-null   bool
#  8   Sentiment.Rating.x        3216 non-null   int64
#  9   Sentiment.Rating.y        3216 non-null   int64
#  10  Calling.Out.x             3216 non-null   int64
#  11  Calling.Out.y             3216 non-null   int64
#  12  Is.About.the.Holocaust.x  2264 non-null   float64
#  13  Is.About.the.Holocaust.y  2264 non-null   float64
#  14  IHRA.Section.x            3216 non-null   int64
#  15  IHRA.Section.y            3216 non-null   int64
#  16  Is.About.The.Holocaust.x  952 non-null    float64
#  17  Is.About.The.Holocaust.y  952 non-null    float64
#  18  Target                    3216 non-null   int64
# dtypes: bool(7), float64(4), int64(7), object(1)
# memory usage: 323.6+ KB

# %%
# print all the data columns tath have null values
df.columns[df.isna().any()].tolist()
# Out:
# ['Is.About.the.Holocaust.x',
#  'Is.About.the.Holocaust.y',
#  'Is.About.The.Holocaust.x',
#  'Is.About.The.Holocaust.y']

# %%
# merge two columns that are same just few values are in one column and rest in other
df['Is.About.the.Holocaust.x'] = df['Is.About.the.Holocaust.x'].fillna(df['Is.About.The.Holocaust.x'])
df['Is.About.the.Holocaust.y'] = df['Is.About.the.Holocaust.y'].fillna(df['Is.About.The.Holocaust.y'])
# drop the unwanted columns 
df.drop(['Is.About.The.Holocaust.x','Is.About.The.Holocaust.y'],inplace=True,axis=1)

# %%
# print all column names
df.columns
# Out:
# Index(['key', 'RT_TF', 'Still.Exists.x', 'Still.Exists.y', 'Sarcasm.x',
#        'Sarcasm.y', 'Disagree.With.x', 'Disagree.With.y', 'Sentiment.Rating.x',
#        'Sentiment.Rating.y', 'Calling.Out.x', 'Calling.Out.y',
#        'Is.About.the.Holocaust.x', 'Is.About.the.Holocaust.y',
#        'IHRA.Section.x', 'IHRA.Section.y', 'Target'],
#       dtype='object')

# %%
# Average out to columns that have same meaning except are filled by different experts
# Approach used: average out the values 
df['Still.Exists'] = df[['Still.Exists.x', 'Still.Exists.y']].mean(axis=1)
df['Sarcasm'] = df[['Sarcasm.x', 'Sarcasm.y']].mean(axis=1)
df['Disagree.With'] = df[['Disagree.With.x', 'Disagree.With.y']].mean(axis=1)
df['Sentiment.Rating'] = df[['Sentiment.Rating.x', 'Sentiment.Rating.y']].mean(axis=1)
df['Is.About.the.Holocaust'] = df[['Is.About.the.Holocaust.x', 'Is.About.the.Holocaust.y']].mean(axis=1)
df['IHRA.Section'] = df[['IHRA.Section.x', 'IHRA.Section.y']].mean(axis=1)
# df['Antisemitism.Rating'] = df[['Antisemitism.Rating.x', 'Antisemitism.Rating.y']].mean(axis=1)
df['Calling.Out'] = df[['Calling.Out.x', 'Calling.Out.y']].mean(axis=1)

# %%
# drop the unwanted columns
df.drop(['Still.Exists.x', 'Still.Exists.y','Sarcasm.x', 'Sarcasm.y','Disagree.With.x', 'Disagree.With.y','Sentiment.Rating.x', 'Sentiment.Rating.y','Is.About.the.Holocaust.x', 'Is.About.the.Holocaust.y'],inplace=True,axis=1)
# df.drop(['IHRA.Section.x', 'IHRA.Section.y','Antisemitism.Rating.x', 'Antisemitism.Rating.y','Calling.Out.x', 'Calling.Out.y'],inplace=True,axis=1)
df.drop(['IHRA.Section.x', 'IHRA.Section.y','Calling.Out.x', 'Calling.Out.y'],inplace=True,axis=1)

# %%
# new data frame in csv file for further predcitive analysis
df.to_csv(file_name[:-4]+str('_filtered.csv'),index=False)

# %% [markdown]
# # Exploraory Data Analysis

# %%
# Input file name
file_name = 'train_dataset.csv'
dataset = pd.read_csv(file_name)

# removed unwanted columns
df['full_text'] = dataset['full_text']

# %%
df.columns
# Out:
# Index(['key', 'RT_TF', 'Target', 'Still.Exists', 'Sarcasm', 'Disagree.With',
#        'Sentiment.Rating', 'Is.About.the.Holocaust', 'IHRA.Section',
#        'Calling.Out', 'full_text'],
#       dtype='object')

# %% [markdown]
# ## Univariate Analysis of each column

# %%
sns.set(rc = {'figure.figsize':(10,8)})

sns.countplot(df.Sarcasm).set(title='Sarcasm feature analysis')
# Out:
# [Text(0.5, 1.0, 'Sarcasm feature analysis')]

# %% [markdown]
# FOR MAJORITY OF COMMENTS, BOTH ANNOTATORS DIDNT FEEL THE LANGUAGE TO BE SARCASTIC AND SHREWD. THUS THE MAJOR COUNT IS ON ZERO,
# A VERY SMALL NUMBER IS WHERE ONE DISAGREED TO ANOTHER, AND EVEN SMALL COUNT FOR THE ANNOTATOS TO FIND THE COMMENT SARCASTIC

# %%
sns.countplot(df.key).set(title='Key feature analysis')
# Out:
# [Text(0.5, 1.0, 'Key feature analysis')]

# %% [markdown]
# DISTRIBUTION OF DATA OVER KEY COLUMN. MAJORITY OF THE COMMENTS BELONG TO JEWSISH ANTI-SEMITISM

# %%
sns.countplot(df['Still.Exists']).set(title='Still Exists analysis')
# Out:
# [Text(0.5, 1.0, 'Still Exists analysis')]

# %% [markdown]
# STILL EXISTS COLUMN VALUE DISTRIBUTION FROM THE 2 ANNOTATORS. THE TWEET WAS STILL ONLINE WHEN ANNOTATOR SAW IT.

# %%
sns.countplot(df['Disagree.With']).set(title='Disagree analysis')
# Out:
# [Text(0.5, 1.0, 'Disagree analysis')]

# %%
sns.countplot(df['Sentiment.Rating']).set(title='Sentimen.Rating analysis')
# Out:
# [Text(0.5, 1.0, 'Sentimen.Rating analysis')]

# %% [markdown]
# AVERAGE SENTIMENT RATING VALUES FROM THE 2 ANNOTATORS. HERE IS WHAT THE DISTRIBUTION OF THEIR AVERAGE VALUES LOOKS LIKE.
# BOTH THE ANNOTATORS GAVE A SENTIMENT RATING AROUND 3 ON A SCALE OF 5. THIS INDICATES THAT MAINLY ANNOTATORS FELT NEUTRAL ABOUT TWEETS.
# AROUND 15% OF TWEETS WERE CONSIDERED NEGATIVE AND A SMALL CHUNK OF AROUND 5%, FELT IT WAS POSITIVE

# %%
sns.countplot(df['IHRA.Section']).set(title='IHRA analysis')
# Out:
# [Text(0.5, 1.0, 'IHRA analysis')]

# %% [markdown]
# THE ANNOTATORS FOLLOWED  https://annotationportal.com/ihra/IHRA.pdf  LINK FOR GIVING A IHRA RATING TO THE TWEETS. MOST VALUES ARE 13.

# %% [markdown]
# ## Correlation Plot

# %%
sns.heatmap(df.corr(),annot=True).set(title='Heatmap of features')
# Out:
# [Text(0.5, 1.0, 'Heatmap of features')]

# %% [markdown]
# CORRELATION PLOT FOR ALL THE DATASETS. HOW DEPENDENT ARE EACH OTHER

# %% [markdown]
# ## Count of each unique key in 'Key' feature

# %%
# Count of each key and bar plot of same
d = df['key'].value_counts()
plt.figure(figsize=(10,10))
plt.title("Data distribution on the basis of the items in 'Key' column")
sns.barplot(d,d.keys())
# Out:
# <AxesSubplot:title={'center':"Data distribution on the basis of the items in 'Key' column"}, xlabel='key'>

# %% [markdown]
# BAR PLOT GIVING A DISTRIBUTION ON THE BASIS OF THE 'KEY' COLUMN.

# %% [markdown]
# ## Text cleaning and Analyis of 'Full Text' feature

# %%
appos = {
"aren't" : "are not",
"can't" : "cannot",
"couldn't" : "could not",
"didn't" : "did not",
"doesn't" : "does not",
"don't" : "do not",
"hadn't" : "had not",
"hasn't" : "has not",
"haven't" : "have not",
"he'd" : "he would",
"he'll" : "he will",
"he's" : "he is",
"i'd" : "I would",
"i'd" : "I had",
"i'll" : "I will",
"i'm" : "I am",
"isn't" : "is not",
"it's" : "it is",
"it'll":"it will",
"i've" : "I have",
"let's" : "let us",
"mightn't" : "might not",
"mustn't" : "must not",
"shan't" : "shall not",
"she'd" : "she would",
"she'll" : "she will",
"she's" : "she is",
"shouldn't" : "should not",
"that's" : "that is",
"wouldn't" : "would not",
"you'd" : "you would",
"you'll" : "you will",
"you're" : "you are",
"you've" : "you have",
"'re": " are",
"wasn't": "was not",
"we'll":" will",
"didn't": "did not",
"there's" : "there is",
"they'd" : "they would",
"they'll" : "they will",
"they're" : "they are",
"they've" : "they have",
"we'd" : "we would",
"we're" : "we are",
"weren't" : "were not",
"we've" : "we have",
"what'll" : "what will",
"what're" : "what are",
"what's" : "what is",
"what've" : "what have",
"where's" : "where is",
"who'd" : "who would",
"who'll" : "who will",
"who're" : "who are",
"who's" : "who is",
"who've" : "who have",
"won't" : "will not"
}

# %%
# lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words('english')
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

# Text cleamning
def clean_text(text):
    text = str(text).lower() # lower case
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    test = re.sub('[^a-zA-Z0-9]+', '', text)
    return text

# Text lemmatization
def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

# Remioving unwanted symbols
df['full_text']=df['full_text'].apply(lambda x: [appos[word] if word in appos else word for word in x.split()])
df['full_text']=df['full_text'].apply(lambda x: ' '.join(x))

# Clean functon call
df['full_text'] = df['full_text'].apply(lambda x:clean_text(x))

# remove square brackets and unnecessary apostrophe symbol
f = lambda df: df['full_text'].split("]")[0].strip('[').strip('"').strip(',')
df['full_text'] = df.apply(f, axis=1)

# Lematize the text
df['full_text'] = df['full_text'].apply(lemmatize_text)

# stop word removal
df['full_text']=df['full_text'].apply(lambda x: [item for item in x if item not in stop_words])

# commas and dot symbol removal and then joining list item into string
df['full_text']=df['full_text'].apply(lambda x: [item.replace(",","") for item in x ])
df['full_text']=df['full_text'].apply(lambda x: [item.replace(".","") for item in x ])
df['full_text']=df['full_text'].apply(lambda x: [' '.join(map(str,x))])

# %%
# cConverting list to string
for i in range(df.shape[0]):
    df['full_text'][i] = df['full_text'][i][0]

# %% [markdown]
# Word Cloud of all data

# %%
print('Word Cloud of all data')
wordcloud2 = WordCloud().generate(' '.join(df['full_text']))
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()
# Out:
# Word Cloud of all data

# %%
print('Word count(top 20) of all data')
df['full_text_temp'] = df['full_text'].apply(lambda x:str(x).split())
# count all words
top = Counter([item for sublist in df['full_text_temp'] for item in sublist])
# new dataframe with the words in top 20 count 
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
# display the words with gradient colors
temp.style.background_gradient(cmap='Blues')
# Out:
# Word count(top 20) of all data
# <style type="text/css">
# #T_84f47_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_84f47_row1_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_84f47_row2_col1, #T_84f47_row3_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_84f47_row4_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_84f47_row5_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_84f47_row6_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_84f47_row7_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_84f47_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_84f47_row9_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_84f47_row10_col1, #T_84f47_row11_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_84f47_row12_col1, #T_84f47_row13_col1, #T_84f47_row14_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_84f47_row15_col1, #T_84f47_row16_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_84f47_row17_col1, #T_84f47_row18_col1, #T_84f47_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_84f47_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84f47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84f47_row0_col0" class="data row0 col0" >jew</td>
#       <td id="T_84f47_row0_col1" class="data row0 col1" >2340</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84f47_row1_col0" class="data row1 col0" >israel</td>
#       <td id="T_84f47_row1_col1" class="data row1 col1" >905</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84f47_row2_col0" class="data row2 col0" >people</td>
#       <td id="T_84f47_row2_col1" class="data row2 col1" >461</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84f47_row3_col0" class="data row3 col0" >amp</td>
#       <td id="T_84f47_row3_col1" class="data row3 col1" >455</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84f47_row4_col0" class="data row4 col0" >wa</td>
#       <td id="T_84f47_row4_col1" class="data row4 col1" >373</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84f47_row5_col0" class="data row5 col0" >u</td>
#       <td id="T_84f47_row5_col1" class="data row5 col1" >293</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_84f47_row6_col0" class="data row6 col0" >jewish</td>
#       <td id="T_84f47_row6_col1" class="data row6 col1" >260</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_84f47_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_84f47_row7_col1" class="data row7 col1" >236</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_84f47_row8_col0" class="data row8 col0" >zionazi</td>
#       <td id="T_84f47_row8_col1" class="data row8 col1" >228</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_84f47_row9_col0" class="data row9 col0" >hate</td>
#       <td id="T_84f47_row9_col1" class="data row9 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_84f47_row10_col0" class="data row10 col0" >nazi</td>
#       <td id="T_84f47_row10_col1" class="data row10 col1" >217</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_84f47_row11_col0" class="data row11 col0" >kike</td>
#       <td id="T_84f47_row11_col1" class="data row11 col1" >215</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_84f47_row12_col0" class="data row12 col0" >ha</td>
#       <td id="T_84f47_row12_col1" class="data row12 col1" >197</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_84f47_row13_col0" class="data row13 col0" >say</td>
#       <td id="T_84f47_row13_col1" class="data row13 col1" >195</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_84f47_row14_col0" class="data row14 col0" >muslim</td>
#       <td id="T_84f47_row14_col1" class="data row14 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_84f47_row15_col0" class="data row15 col0" >trump</td>
#       <td id="T_84f47_row15_col1" class="data row15 col1" >186</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_84f47_row16_col0" class="data row16 col0" >fucking</td>
#       <td id="T_84f47_row16_col1" class="data row16 col1" >186</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_84f47_row17_col0" class="data row17 col0" >one</td>
#       <td id="T_84f47_row17_col1" class="data row17 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_84f47_row18_col0" class="data row18 col0" >get</td>
#       <td id="T_84f47_row18_col1" class="data row18 col1" >176</td>
#     </tr>
#     <tr>
#       <th id="T_84f47_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_84f47_row19_col0" class="data row19 col0" >antisemitism</td>
#       <td id="T_84f47_row19_col1" class="data row19 col1" >175</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.drop(['full_text_temp'],inplace=True,axis=1)
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in all data', orientation='h', 
             width=500, height=500,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="91fb5f92-0d61-4bbb-ba64-fb54e4485de7" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91fb5f92-0d61-4bbb-ba64-fb54e4485de7")) {                    Plotly.newPlot(                        "91fb5f92-0d61-4bbb-ba64-fb54e4485de7",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"jew","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"jew","offsetgroup":"jew","orientation":"h","showlegend":true,"textposition":"auto","x":[2340],"xaxis":"x","y":["jew"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"israel","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"israel","offsetgroup":"israel","orientation":"h","showlegend":true,"textposition":"auto","x":[905],"xaxis":"x","y":["israel"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"people","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"people","offsetgroup":"people","orientation":"h","showlegend":true,"textposition":"auto","x":[461],"xaxis":"x","y":["people"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"amp","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"amp","offsetgroup":"amp","orientation":"h","showlegend":true,"textposition":"auto","x":[455],"xaxis":"x","y":["amp"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"wa","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"wa","offsetgroup":"wa","orientation":"h","showlegend":true,"textposition":"auto","x":[373],"xaxis":"x","y":["wa"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"u","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"u","offsetgroup":"u","orientation":"h","showlegend":true,"textposition":"auto","x":[293],"xaxis":"x","y":["u"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"jewish","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"jewish","offsetgroup":"jewish","orientation":"h","showlegend":true,"textposition":"auto","x":[260],"xaxis":"x","y":["jewish"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"like","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[236],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"zionazi","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"zionazi","offsetgroup":"zionazi","orientation":"h","showlegend":true,"textposition":"auto","x":[228],"xaxis":"x","y":["zionazi"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"hate","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"hate","offsetgroup":"hate","orientation":"h","showlegend":true,"textposition":"auto","x":[219],"xaxis":"x","y":["hate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"nazi","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"nazi","offsetgroup":"nazi","orientation":"h","showlegend":true,"textposition":"auto","x":[217],"xaxis" ...

# %%
# Print unique keys and their count
df['key'].value_counts()
# Out:
# JewNAS        1763
# IsraelNAS      505
# ZioNaziAS      365
# JewAS          222
# KikesNAS       150
# KikesAS         79
# IsraelAS        77
# ZioNaziNAS      55
# Name: key, dtype: int64

# %%
# Function to create word cloud of each key
def cloud(df,clm,key):
  jewnas = df.loc[df["key"] == key, ["key","full_text"]]
  wordcloud2 = WordCloud().generate(' '.join(jewnas['full_text']))
  return wordcloud2

# funciton to get top 20 words of each key
def top20(key):
  jewnas = df.loc[df["key"] == key, ["key","full_text"]]
  top = Counter([item for sublist in jewnas['full_text'].apply(lambda x:str(x).split()) for item in sublist])
  return(top.most_common(20))

# function to get common tuples in two lists of tuples
def common(jnas,jas):
  jnas[0] = list(jnas[0])
  jnas[1] = list(jnas[1])
  p=[]
  comon = set(jnas[0])&set(jas[0])
  for i in comon:
    p.append((i, jnas[1][jnas[0].index(i)],jas[1][jas[0].index(i)]))
  dt = pd.DataFrame.from_records(p, columns =['Common word', 'Count in NAS','Count in AS'])
  return(dt)

# %%
## JEW NAS word cloud
from matplotlib.pyplot import figure
fig, ax = plt.subplots(4, 2, figsize=(20,6))
plt.subplots_adjust(wspace=0.02, hspace=0.001)

## Jew NAS word cloud
plt.subplot(2, 4, 1)
plt.imshow(cloud(df,'full_text','JewNAS'))
plt.axis("off")
plt.title('JEW NAS')

## Israel NAS word cloud
plt.subplot(2, 4, 2)
plt.imshow(cloud(df,'full_text','IsraelNAS'))
plt.axis("off")
plt.title('Israel NAS')

## ZioNazi AS word cloud
plt.subplot(2, 4, 3)
plt.imshow(cloud(df,'full_text','ZioNaziNAS'))
plt.axis("off")
plt.title('Zionazi AS')

## Kike NAS word cloud
plt.subplot(2, 4, 4)
plt.imshow(cloud(df,'full_text','KikesNAS'))
plt.axis("off")
plt.title('Kike NAS')

## ------- AS category 

## JEW AS word cloud
plt.subplot(2, 4, 5)
plt.imshow(cloud(df,'full_text','JewNAS'))
plt.axis("off")
plt.title('JEW AS')

## Israel AS word cloud
plt.subplot(2, 4, 6)
plt.imshow(cloud(df,'full_text','IsraelNAS'))
plt.axis("off")
plt.title('Israel AS')

## ZioNazi AS word cloud
plt.subplot(2, 4, 7)
plt.imshow(cloud(df,'full_text','ZioNaziAS'))
plt.axis("off")
plt.title('Zionazi AS')

## Kike AS word cloud
plt.subplot(2, 4, 8)
plt.imshow(cloud(df,'full_text','KikesAS'))
plt.axis("off")
plt.title('Kike AS')
# Out:
# Text(0.5, 1.0, 'Kike AS')

# %%
# store top20 words of each group in a list
jnas = list(zip(*top20('JewNAS')))
inas = list(zip(*top20('IsraelNAS')))
znas = list(zip(*top20('ZioNaziNAS')))
knas = list(zip(*top20('KikesNAS')))

jas = list(zip(*top20('JewAS')))
ias = list(zip(*top20('IsraelAS')))
zas = list(zip(*top20('ZioNaziAS')))
kas = list(zip(*top20('KikesAS')))

# %%
# print common words in all NAS
print(set(jnas[0])&set(inas[0])&set(znas[0])&set(knas[0]))

# print common words in all AS
print(set(jas[0])&set(ias[0])&set(zas[0])&set(kas[0]))
# Out:
# set()
# set()

# %%
# Print common words in JewNAS and JewAS
print('Jews')

common(jnas,jas).style.background_gradient(cmap='Blues')
# Out:
# Jews
# <style type="text/css">
# #T_fd7fe_row0_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_fd7fe_row0_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_fd7fe_row1_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_fd7fe_row1_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_fd7fe_row2_col1, #T_fd7fe_row11_col2, #T_fd7fe_row13_col1, #T_fd7fe_row13_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_fd7fe_row2_col2, #T_fd7fe_row5_col2, #T_fd7fe_row6_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_fd7fe_row3_col1, #T_fd7fe_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fd7fe_row4_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_fd7fe_row4_col2, #T_fd7fe_row6_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_fd7fe_row5_col1, #T_fd7fe_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fd7fe_row7_col1, #T_fd7fe_row7_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_fd7fe_row8_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_fd7fe_row9_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_fd7fe_row9_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_fd7fe_row10_col1, #T_fd7fe_row11_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_fd7fe_row10_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_fd7fe_row12_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_fd7fe_row12_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# </style>
# <table id="T_fd7fe_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common word</th>
#       <th class="col_heading level0 col1" >Count in NAS</th>
#       <th class="col_heading level0 col2" >Count in AS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd7fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd7fe_row0_col0" class="data row0 col0" >wa</td>
#       <td id="T_fd7fe_row0_col1" class="data row0 col1" >249</td>
#       <td id="T_fd7fe_row0_col2" class="data row0 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd7fe_row1_col0" class="data row1 col0" >amp</td>
#       <td id="T_fd7fe_row1_col1" class="data row1 col1" >288</td>
#       <td id="T_fd7fe_row1_col2" class="data row1 col2" >22</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd7fe_row2_col0" class="data row2 col0" >one</td>
#       <td id="T_fd7fe_row2_col1" class="data row2 col1" >118</td>
#       <td id="T_fd7fe_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd7fe_row3_col0" class="data row3 col0" >jew</td>
#       <td id="T_fd7fe_row3_col1" class="data row3 col1" >1999</td>
#       <td id="T_fd7fe_row3_col2" class="data row3 col2" >246</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd7fe_row4_col0" class="data row4 col0" >u</td>
#       <td id="T_fd7fe_row4_col1" class="data row4 col1" >162</td>
#       <td id="T_fd7fe_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd7fe_row5_col0" class="data row5 col0" >white</td>
#       <td id="T_fd7fe_row5_col1" class="data row5 col1" >97</td>
#       <td id="T_fd7fe_row5_col2" class="data row5 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd7fe_row6_col0" class="data row6 col0" >say</td>
#       <td id="T_fd7fe_row6_col1" class="data row6 col1" >126</td>
#       <td id="T_fd7fe_row6_col2" class="data row6 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd7fe_row7_col0" class="data row7 col0" >jewish</td>
#       <td id="T_fd7fe_row7_col1" class="data row7 col1" >186</td>
#       <td id="T_fd7fe_row7_col2" class="data row7 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd7fe_row8_col0" class="data row8 col0" >ha</td>
#       <td id="T_fd7fe_row8_col1" class="data row8 col1" >110</td>
#       <td id="T_fd7fe_row8_col2" class="data row8 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fd7fe_row9_col0" class="data row9 col0" >muslim</td>
#       <td id="T_fd7fe_row9_col1" class="data row9 col1" >153</td>
#       <td id="T_fd7fe_row9_col2" class="data row9 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fd7fe_row10_col0" class="data row10 col0" >israel</td>
#       <td id="T_fd7fe_row10_col1" class="data row10 col1" >164</td>
#       <td id="T_fd7fe_row10_col2" class="data row10 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fd7fe_row11_col0" class="data row11 col0" >nazi</td>
#       <td id="T_fd7fe_row11_col1" class="data row11 col1" >171</td>
#       <td id="T_fd7fe_row11_col2" class="data row11 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fd7fe_row12_col0" class="data row12 col0" >people</td>
#       <td id="T_fd7fe_row12_col1" class="data row12 col1" >325</td>
#       <td id="T_fd7fe_row12_col2" class="data row12 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_fd7fe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fd7fe_row13_col0" class="data row13 col0" >like</td>
#       <td id="T_fd7fe_row13_col1" class="data row13 col1" >115</td>
#       <td id="T_fd7fe_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print common words in IsraelAS and IsraelAS
print('Israel')

common(inas,ias).style.background_gradient(cmap='Blues')
# Out:
# Israel
# <style type="text/css">
# #T_08c5c_row0_col1, #T_08c5c_row0_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_08c5c_row1_col1, #T_08c5c_row4_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_08c5c_row1_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_08c5c_row2_col1, #T_08c5c_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_08c5c_row3_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_08c5c_row3_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_08c5c_row4_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_08c5c_row5_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_08c5c_row5_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_08c5c_row6_col1, #T_08c5c_row6_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_08c5c_row7_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_08c5c_row7_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_08c5c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common word</th>
#       <th class="col_heading level0 col1" >Count in NAS</th>
#       <th class="col_heading level0 col2" >Count in AS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08c5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08c5c_row0_col0" class="data row0 col0" >wa</td>
#       <td id="T_08c5c_row0_col1" class="data row0 col1" >50</td>
#       <td id="T_08c5c_row0_col2" class="data row0 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_08c5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08c5c_row1_col0" class="data row1 col0" >amp</td>
#       <td id="T_08c5c_row1_col1" class="data row1 col1" >48</td>
#       <td id="T_08c5c_row1_col2" class="data row1 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_08c5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_08c5c_row2_col0" class="data row2 col0" >one</td>
#       <td id="T_08c5c_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_08c5c_row2_col2" class="data row2 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_08c5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_08c5c_row3_col0" class="data row3 col0" >u</td>
#       <td id="T_08c5c_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_08c5c_row3_col2" class="data row3 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_08c5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_08c5c_row4_col0" class="data row4 col0" >palestinian</td>
#       <td id="T_08c5c_row4_col1" class="data row4 col1" >47</td>
#       <td id="T_08c5c_row4_col2" class="data row4 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_08c5c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_08c5c_row5_col0" class="data row5 col0" >ha</td>
#       <td id="T_08c5c_row5_col1" class="data row5 col1" >41</td>
#       <td id="T_08c5c_row5_col2" class="data row5 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_08c5c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_08c5c_row6_col0" class="data row6 col0" >israel</td>
#       <td id="T_08c5c_row6_col1" class="data row6 col1" >550</td>
#       <td id="T_08c5c_row6_col2" class="data row6 col2" >82</td>
#     </tr>
#     <tr>
#       <th id="T_08c5c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_08c5c_row7_col0" class="data row7 col0" >people</td>
#       <td id="T_08c5c_row7_col1" class="data row7 col1" >33</td>
#       <td id="T_08c5c_row7_col2" class="data row7 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print common words in ZioNaziNAS and ZioNaziAS
print('ZioNazi')

common(znas,zas).style.background_gradient(cmap='Blues')
# Out:
# ZioNazi
# <style type="text/css">
# #T_33b52_row0_col1, #T_33b52_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_33b52_row1_col1, #T_33b52_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_33b52_row1_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_33b52_row2_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# </style>
# <table id="T_33b52_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common word</th>
#       <th class="col_heading level0 col1" >Count in NAS</th>
#       <th class="col_heading level0 col2" >Count in AS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33b52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33b52_row0_col0" class="data row0 col0" >zionazi</td>
#       <td id="T_33b52_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_33b52_row0_col2" class="data row0 col2" >197</td>
#     </tr>
#     <tr>
#       <th id="T_33b52_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33b52_row1_col0" class="data row1 col0" >zionazis</td>
#       <td id="T_33b52_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_33b52_row1_col2" class="data row1 col2" >132</td>
#     </tr>
#     <tr>
#       <th id="T_33b52_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33b52_row2_col0" class="data row2 col0" >amp</td>
#       <td id="T_33b52_row2_col1" class="data row2 col1" >17</td>
#       <td id="T_33b52_row2_col2" class="data row2 col2" >56</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print common words in KikesNAS and KikesAS
print('Kikes')
common(knas,kas).style.background_gradient(cmap='Blues')
# Out:
# Kikes
# <style type="text/css">
# #T_31708_row0_col1, #T_31708_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_31708_row0_col2, #T_31708_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31708_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common word</th>
#       <th class="col_heading level0 col1" >Count in NAS</th>
#       <th class="col_heading level0 col2" >Count in AS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31708_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31708_row0_col0" class="data row0 col0" >kike</td>
#       <td id="T_31708_row0_col1" class="data row0 col1" >137</td>
#       <td id="T_31708_row0_col2" class="data row0 col2" >78</td>
#     </tr>
#     <tr>
#       <th id="T_31708_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31708_row1_col0" class="data row1 col0" >fucking</td>
#       <td id="T_31708_row1_col1" class="data row1 col1" >161</td>
#       <td id="T_31708_row1_col2" class="data row1 col2" >6</td>
#     </tr>
#   </tbody>
# </table>
